# %%
import matplotlib.pyplot as plt

# %%
skill = ['General Programming','Python','Visualization','Graphic Design','Data Analytics']
rating = [5,6,7,4,7]

# %%
plt.bar(skill, rating, color ='crimson')
plt.xticks(rotation=90)
plt.title("Neel's experience rating")
# Out:
# Text(0.5, 1.0, "Neel's experience rating")

# %% [markdown]
# I have chosen to display my data in the form of a bar chart because they are easy to understand, widely used and display relative numbers or proportions of multiple categories. As we can clearly infer from my graph that my expertise is in visualization and data analytics as compared to the other skills.
